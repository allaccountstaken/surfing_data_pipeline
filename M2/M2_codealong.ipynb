# %%
# Extract data for a view studies from Roper Center for Public Opinion Research

# %%
import os
import numpy as np
import pandas as pd

from google.colab import drive
from google.colab import files
import io

# %%
# Mount the drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Upload data file
uploaded = files.upload()
# Out:
#      <input type="file" id="files-05a9bede-2d53-4d96-9f31-339eaba738b7" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-05a9bede-2d53-4d96-9f31-339eaba738b7">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving USAIPO1936-0053.csv to USAIPO1936-0053.csv

# %%
pd.set_option('display.max_columns', 10) #display a maximumn of 10 columns
pd.set_option('display.max_rows', 10) #display a maximumn of 10 rows

# %%
gallup1936 = pd.read_csv('USAIPO1936-0053.csv')

# %%
gallup1936.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5515 entries, 0 to 5514
# Data columns (total 44 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   form           0 non-null      float64
#  1   state          5515 non-null   object
#  2   region         5515 non-null   object
#  3   female         5514 non-null   object
#  4   age            5169 non-null   object
#  5   class          4619 non-null   object
#  6   OCCUPATION1    5513 non-null   object
#  7   OCCUPATION2    0 non-null      float64
#  8   OCCUPATION3    0 non-null      float64
#  9   black          2058 non-null   object
#  10  size           5514 non-null   object
#  11  education      0 non-null      float64
#  12  AGE_3WAY       0 non-null      float64
#  13  AGE40          0 non-null      float64
#  14  OCC8           5513 non-null   object
#  15  prof           5513 non-null   object
#  16  REGION4        5515 non-null   object
# ...

# %% [markdown]
# STATA data file

# %%
# Upload data file
uploaded = files.upload()
# Out:
#      <input type="file" id="files-869ab11a-b29a-4d6b-936e-7c6a2e8c30e7" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-869ab11a-b29a-4d6b-936e-7c6a2e8c30e7">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving 31119104.DTA to 31119104.DTA

# %%
kaiser2021 = pd.read_stata('31119104.DTA')

# %%
kaiser2021.head()
# Out:
#          id BIDENT1                userdata  ...         state       usr   USR_NEW
# 0  00000002     web  SSRS Probability Panel  ...      NEW YORK     Rural     Rural
# 1  00000003     web  SSRS Probability Panel  ...      michigan     Urban     Urban
# 2  00000004     web  SSRS Probability Panel  ...      virginia  Suburban  Suburban
# 3  00000005     web  SSRS Probability Panel  ...       florida  Suburban  Suburban
# 4  00000006     web  SSRS Probability Panel  ...  NORTH DAKOTA     Rural     Rural
#
# [5 rows x 79 columns]

# %%
#dispalay 80 rows?
kaiser2021.head(1).T
# Out:
#                                0
# id                      00000002
# BIDENT1                      web
# userdata  SSRS Probability Panel
# language                 English
# INT1A                        NaN
# ...                          ...
# CDC2013                 Non-core
# CDC2013U         Rural (CDC=4-6)
# state                   NEW YORK
# usr                        Rural
# USR_NEW                    Rural
#
# [79 rows x 1 columns]

# %%
kaiser2021.state.value_counts()
# Out:
# california              101
# texas                    79
# florida                  61
# refused                  56
# NEW YORK                 52
# pennsylvania             41
# NORTH CAROLINA           38
# virginia                 37
# illinois                 37
# georgia                  34
# indiana                  29
# ohio                     29
# arizona                  27
# wisconsin                27
# NEW JERSEY               27
# minnesota                24
# washington               24
# SOUTH CAROLINA           22
# colorado                 21
# maryland                 19
# missouri                 19
# michigan                 19
# tennessee                16
# utah                     16
# iowa                     15
# connecticut              15
# massachusetts            15
# oregon                   13
# louisiana                12
# alabama                  12
# kansas                   11
# mississippi              11
# nevada                   11
# ...

# %%
# Upload data file
uploaded = files.upload()
# Out:
#      <input type="file" id="files-6133489f-9342-45f2-b70b-72c6c69adc7d" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-6133489f-9342-45f2-b70b-72c6c69adc7d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving i20068.dat to i20068.dat

# %%
# Upload data file
uploaded = files.upload()
# Out:
#      <input type="file" id="files-e7a323ab-433a-44c7-86dd-a6d46fd76c22" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-e7a323ab-433a-44c7-86dd-a6d46fd76c22">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving poll_widths_ds6001 - Sheet1.csv to poll_widths_ds6001 - Sheet1.csv
