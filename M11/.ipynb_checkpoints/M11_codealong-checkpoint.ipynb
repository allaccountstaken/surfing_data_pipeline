# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os
# %matplotlib inline

# %%
os.chdir("/Users/dmitrymikhaylov/Documents/learn/uva/spring2022/DS6001/surfing_data_pipeline/M10")

# %%
house = pd.read_csv('ahs_cleaned-1.csv', index_col=0)

# %%
house.head(1).T
# Out:
#                                                            0
# DIVISION                                      South Atlantic
# TENURE     Owned or being bought by someone in your house...
# YRBUILT                                                 2000
# UNITSIZE                          2,000 to 2,499 square feet
# HSHLDTYPE                    Married-couple family household
# HHRACE                                            White only
# HHSEX                                                   Male
# HINCP                                                 257000
# TOTHCAMT                                                1642
# MARKETVAL                                             280249
# MAINTAMT                                                1022
# FUSEBLOW      No fuses / breakers blown in the last 3 months
# SEWBREAK                  No breakdowns in the last 3 months
# ROACH                         No signs in the last 12 months
# RODENT                        No signs in the last 12 months
# NOWIRE                                            Not broken
# PLUGS                                             Not broken
# COLD                                              Not broken
# NOTOIL                                            Not broken
# NOWAT                                             Not broken
# FLOORHOLE                                         Not broken
# FNDCRUMB                                          Not broken
# PAINTPEEL                                         Not broken
# ROOFHOLE                                          Not broken
# ROOFSAG                                           Not broken
# ROOFSHIN                                          Not broken
# WALLCRACK                                         Not broken
# WALLSIDE                                          Not broken
# WALLSLOPE                                         Not broken
# WINBOARD                                          Not broken
# WINBROKE                                          Not broken
# LEAKI                                             Not broken
# MOLDBATH                                          Not broken

# %% [markdown]
# ## Distributions

# %%
house.columns
# Out:
# Index(['DIVISION', 'TENURE', 'YRBUILT', 'UNITSIZE', 'HSHLDTYPE', 'HHRACE',
#        'HHSEX', 'HINCP', 'TOTHCAMT', 'MARKETVAL', 'MAINTAMT', 'FUSEBLOW',
#        'SEWBREAK', 'ROACH', 'RODENT', 'NOWIRE', 'PLUGS', 'COLD', 'NOTOIL',
#        'NOWAT', 'FLOORHOLE', 'FNDCRUMB', 'PAINTPEEL', 'ROOFHOLE', 'ROOFSAG',
#        'ROOFSHIN', 'WALLCRACK', 'WALLSIDE', 'WALLSLOPE', 'WINBOARD',
#        'WINBROKE', 'LEAKI', 'MOLDBATH'],
#       dtype='object')

# %%
house2 = house.query("HINCP > 0")
# Log10 to show number of 0s on one's income
house2['logincome'] = np.log(house2.HINCP)/np.log(10)
plt.figure(figsize=(12, 5))
sns.distplot(house2.logincome, kde=True, bins=200)
plt.ylabel("Frequency")
plt.xlabel("Houssehold Income (Log base 10)")
plt.title("Distribution of Household Income")
plt.show()
# Out:
# <ipython-input-29-062826796d82>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house2['logincome'] = np.log(house2.HINCP)/np.log(10)

# %%
plt.figure(figsize=(12, 5))
sns.distplot(house2.logincome, hist=False, kde=True, bins=200, color='gold')
plt.ylabel("Frequency")
plt.xlabel("Houssehold Income (Log base 10)")
plt.title("Distribution of Household Income")
plt.show()

# %%
plt.figure(figsize=(12, 5))
sns.kdeplot(house2.logincome, shade=True, color='red')
plt.ylabel("Frequency")
plt.xlabel("Household Income (Log-base-10)")
plt.title("Distribution of Household Income")
plt.show()

# %%
house2.TENURE.value_counts()
# Out:
# Owned or being bought by someone in your household    32539
# Rented                                                20110
# Occupied without payment of rent                        696
# Name: TENURE, dtype: int64

# %%
plt.figure(figsize=(12, 5))
sns.kdeplot(house2.query("TENURE =='Owned or being bought by someone in your household'").logincome, 
            shade=True, label='Owned')
sns.kdeplot(house2.query("TENURE =='Rented'").logincome, 
            shade=True, label='Rent')
plt.ylabel("Frequency")
plt.xlabel("Household Income (Log-base-10)")
plt.title("Distribution of Household Income")
plt.legend()
plt.show()

# %% [markdown]
# ## Bar plot: own vs rent, broken down by race

# %%
house_agg1 = house.groupby(['HHRACE', 'TENURE']).size().reset_index().rename({0:'Count'}, axis=1)

# %%
house_agg1
# Out:
#                                  HHRACE  \
# 0   American Indian, Alaska Native only
# 1   American Indian, Alaska Native only
# 2   American Indian, Alaska Native only
# 3                            Asian only
# 4                            Asian only
# 5                            Asian only
# 6                            Black only
# 7                            Black only
# 8                            Black only
# 9                                 Other
# 10                                Other
# 11                                Other
# 12                        White / Black
# 13                        White / Black
# 14                        White / Black
# 15                           White only
# 16                           White only
# 17                           White only
#
#                                                TENURE  Count
# 0                    Occupied without payment of rent     18
# 1   Owned or being bought by someone in your house...    274
# 2                                              Rented    311
# 3                    Occupied without payment of rent     40
# 4   Owned or being bought by someone in your house...   2117
# 5                                              Rented   1432
# 6                    Occupied without payment of rent    118
# 7   Owned or being bought by someone in your house...   3177
# 8                                              Rented   4920
# 9                    Occupied without payment of rent     11
# 10  Owned or being bought by someone in your house...    389
# 11                                             Rented    351
# 12                   Occupied without payment of rent      2
# 13  Owned or being bought by someone in your house...     60
# 14                                             Rented    119
# 15                   Occupied without payment of rent    551
# 16  Owned or being bought by someone in your house...  26955
# 17                                             Rented  13610

# %%
plt.figure(figsize=(15,6))
sns.barplot(x='HHRACE', y='Count', hue='TENURE', data=house_agg1, palette="mako")
plt.show()

# %%
house_agg2 = house.groupby(['HHRACE', 'TENURE']).size().reset_index().rename({0:'Total'}, axis=1)
house_agg = pd.merge(house_agg1, house_agg2, how='inner', on='HHRACE')

# %%
house_agg['Percent']= house_agg['Count']/house_agg['Total']

# %%
house_agg
# Out:
#                                  HHRACE  \
# 0   American Indian, Alaska Native only
# 1   American Indian, Alaska Native only
# 2   American Indian, Alaska Native only
# 3   American Indian, Alaska Native only
# 4   American Indian, Alaska Native only
# 5   American Indian, Alaska Native only
# 6   American Indian, Alaska Native only
# 7   American Indian, Alaska Native only
# 8   American Indian, Alaska Native only
# 9                            Asian only
# 10                           Asian only
# 11                           Asian only
# 12                           Asian only
# 13                           Asian only
# 14                           Asian only
# 15                           Asian only
# 16                           Asian only
# 17                           Asian only
# 18                           Black only
# 19                           Black only
# 20                           Black only
# 21                           Black only
# 22                           Black only
# 23                           Black only
# 24                           Black only
# 25                           Black only
# 26                           Black only
# 27                                Other
# 28                                Other
# 29                                Other
# 30                                Other
# 31                                Other
# 32                                Other
# 33                                Other
# 34                                Other
# 35                                Other
# 36                        White / Black
# 37                        White / Black
# 38                        White / Black
# 39                        White / Black
# 40                        White / Black
# 41                        White / Black
# 42                        White / Black
# 43                        White / Black
# 44                        White / Black
# 45                           White only
# 21                   Occupied without payment of rent    118  26.923729
# 22  Owned or being bought by someone in your house...   3177   1.000000
# 23                                             Rented   4920   0.645732
# 24                   Occupied without payment of rent    118  41.694915
# 25  Owned or being bought by someone in your house...   3177   1.548631
# 26                                             Rented   4920   1.000000
# 27                   Occupied without payment of rent     11   1.000000
# 28  Owned or being bought by someone in your house...    389   0.028278
# 29                                             Rented    351   0.031339
# 30                   Occupied without payment of rent     11  35.363636
# 31  Owned or being bought by someone in your house...    389   1.000000
# 32                                             Rented    351   1.108262
# 33                   Occupied without payment of rent     11  31.909091
# 34  Owned or being bought by someone in your house...    389   0.902314
# 35                                             Rented    351   1.000000
# 36                   Occupied without payment of rent      2   1.000000
# 37  Owned or being bought by someone in your house...     60   0.033333
# 38                                             Rented    119   0.016807
# 39                   Occupied without payment of rent      2  30.000000
# 40  Owned or being bought by someone in your house...     60   1.000000
# 41                                             Rented    119   0.504202
# 42                   Occupied without payment of rent      2  59.500000
# 43  Owned or being bought by someone in your house...     60   1.983333
# 44                                             Rented    119   1.000000
# 45                   Occupied without payment of rent    551   1.000000
# 46  Owned or being bought by someone in your house...  26955   0.020441
# 47                                             Rented  13610   0.040485
# 48                   Occupied without payment of rent    551  48.920145
# 49  Owned or being bought by someone in your house...  26955   1.000000
# 50                                             Rented  13610   1.980529
# 51                   Occupied without payment of rent    551  24.700544
# 52  Owned or being bought by someone in your house...  26955   0.504916
# 53                                             Rented  13610   1.000000

# %%
plt.figure(figsize=(15,6))
sns.barplot(x='HHRACE', y='Percent', hue='TENURE_x', data=house_agg, palette="magma")
plt.show()

# %% [markdown]
# ## Box plot: income by tenure

# %%
plt.figure(figsize=(12, 6))
sns.boxplot(y='HHRACE', x='logincome', data=house2, palette='Paired')
plt.show()

# %% [markdown]
# ## Scatter plot: income by year built, color by race

# %%
plt.figure(figsize=(15, 6))
sns.scatterplot(y='logincome', x='YRBUILT', hue='HHRACE', data=house2)
plt.show()

# %% [markdown]
# ## Line plot: median income by year built

# %%
house_agg = house.groupby('YRBUILT').agg({'HINCP':'median'}).reset_index()
house_agg.head()
# Out:
#    YRBUILT    HINCP
# 0     1919  41500.0
# 1     1920  39985.0
# 2     1930  39330.0
# 3     1940  37400.0
# 4     1950  47200.0

# %%
plt.figure(figsize=(15, 6))
sns.lineplot(y='HINCP', x='YRBUILT',  data=house_agg, color='black')
plt.show()

# %%
house.YRBUILT.value_counts()
# Out:
# 1970    9313
# 1980    9072
# 2000    8883
# 1990    7863
# 1960    6860
# 1950    6330
# 1919    3594
# 1940    3001
# 1920    2494
# 1930    1699
# 2010     846
# 2017     503
# 2016     489
# 2015     486
# 2014     444
# 2013     340
# 2012     320
# 2018     269
# 2011     251
# 2019     128
# Name: YRBUILT, dtype: int64

# %% [markdown]
# ## Facet grid: total expenses by tenure, facet grid by race

# %%
house['logexpense'] = np.log(house['TOTHCAMT'])/np.log(10)
g = sns.FacetGrid(house, col='HHRACE', col_wrap=3, height=4, aspect=1)
g.map(sns.boxplot, 'logexpense', 'TENURE')
plt.show()
# Out:
# /Users/dmitrymikhaylov/opt/anaconda3/lib/python3.8/site-packages/pandas/core/arraylike.py:397: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /Users/dmitrymikhaylov/opt/anaconda3/lib/python3.8/site-packages/pandas/core/arraylike.py:397: RuntimeWarning: invalid value encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /Users/dmitrymikhaylov/opt/anaconda3/lib/python3.8/site-packages/seaborn/axisgrid.py:723: UserWarning: Using the boxplot function without specifying `order` is likely to produce an incorrect plot.
#   warnings.warn(warning)
