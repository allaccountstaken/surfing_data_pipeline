# %% [markdown]
# # Lab Assignment 10: Exploratory Data Analysis, Part 1
# ## DS 6001: Practice and Application of Data Science
#
# ### Instructions
# Please answer the following questions as completely as possible using text, code, and the results of code as needed. Format your answers in a Jupyter notebook. To receive full credit, make sure you address every part of the problem, and make sure your document is formatted in a clean and professional way.
#
# In this lab, you will be working with the 2018 [General Social Survey (GSS)](http://www.gss.norc.org/). The GSS is a sociological survey created and regularly collected since 1972 by the National Opinion Research Center at the University of Chicago. It is funded by the National Science Foundation. The GSS collects information and keeps a historical record of the concerns, experiences, attitudes, and practices of residents of the United States, and it is one of the most important data sources for the social sciences.
#
# The data includes features that measure concepts that are notoriously difficult to ask about directly, such as religion, racism, and sexism. The data also include many different metrics of how successful a person is in his or her profession, including income, socioeconomic status, and occupational prestige. These occupational prestige scores are coded separately by the GSS.  The full description of their methodology for measuring prestige is available here: http://gss.norc.org/Documents/reports/methodological-reports/MR122%20Occupational%20Prestige.pdf Here's a quote to give you an idea about how these scores are calculated:
#
# > Respondents then were given small cards which each had a single occupational titles listed on it. Cards were in English or Spanish. They were given one card at a time in the preordained order. The interviewer then asked the respondent to "please put the card in the box at the top of the ladder if you think that occupation has the highest possible social standing. Put it in the box of the bottom of the ladder if you think it has the lowest possible social standing. If it belongs somewhere in between, just put it in the box that matches the social standing of the occupation."
#
# The prestige scores are calculated from the aggregated rankings according to the method described above.

# %% [markdown]
# ### Problem 0
# Import the following packages:

# %%
import numpy as np
import pandas as pd
import sidetable
import weighted # this is a module of wquantiles, so type pip install wquantiles or conda install wquantiles to get access to it
from scipy import stats 
from sklearn import manifold
from sklearn import metrics
import prince
from pandas_profiling import ProfileReport
pd.options.display.max_columns = None

# %% [markdown]
# Then load the GSS data with the following code:

# %%
# %%capture
gss = pd.read_csv("https://github.com/jkropko/DS-6001/raw/master/localdata/gss2018.csv",
                 encoding='cp1252', na_values=['IAP','IAP,DK,NA,uncodeable', 'NOT SURE',
                                               'DK', 'IAP, DK, NA, uncodeable', '.a', "CAN'T CHOOSE"])

# %% [markdown]
# ### Problem 1
# Drop all columns except for the following:
# * `id` - a numeric unique ID for each person who responded to the survey
# * `wtss` - survey sample weights
# * `sex` - male or female
# * `educ` - years of formal education
# * `region` - region of the country where the respondent lives
# * `age` - age
# * `coninc` - the respondent's personal annual income
# * `prestg10` - the respondent's occupational prestige score, as measured by the GSS using the methodology described above
# * `mapres10` - the respondent's mother's occupational prestige score, as measured by the GSS using the methodology described above
# * `papres10` -the respondent's father's occupational prestige score, as measured by the GSS using the methodology described above
# * `sei10` - an index measuring the respondent's socioeconomic status
# * `satjob` - responses to "On the whole, how satisfied are you with the work you do?"
# * `fechld` - agree or disagree with: "A working mother can establish just as warm and secure a relationship with her children as a mother who does not work."
# * `fefam` - agree or disagree with: "It is much better for everyone involved if the man is the achiever outside the home and the woman takes care of the home and family."
# * `fepol` - agree or disagree with: "Most men are better suited emotionally for politics than are most women."
# * `fepresch` - agree or disagree with: "A preschool child is likely to suffer if his or her mother works."
# * `meovrwrk` - agree or disagree with: "Family life often suffers because men concentrate too much on their work."
#
# Then rename any columns with names that are non-intuitive to you to more intuitive and descriptive ones. Finally, replace the "89 or older" values of `age` with 89, and convert `age` to a float data type. [1 point]

# %%
# Create a list to hold selected features names -- total 17 of them:
selected_fetures = ['id', 'wtss', 'sex', 'educ', 
                    'region', 'age', 'coninc', 'prestg10', 
                    'mapres10', 'papres10', 'sei10', 'satjob', 
                    'fechld', 'fefam', 'fepol', 'fepresch', 'meovrwrk']
len(selected_fetures)
# Out:
# 17

# %%
gss.head()
# Out:
#   abany abdefect    abfelegl abhelp1 abhelp2 abhelp3 abhelp4 abhlth  \
# 0    no      yes         NaN     yes     yes     yes     yes    yes
# 1   yes      yes  it depends      no      no      no      no    yes
# 2   NaN      NaN         NaN     yes      no     yes     yes    NaN
# 3   NaN      NaN      should     yes     yes     yes     yes    NaN
# 4    no      yes         NaN      no      no      no     yes    yes
#
#                     abinspay  \
# 0      people should be able
# 1  people should not be able
# 2  people should not be able
# 3      people should be able
# 4  people should not be able
#
#                                            abmedgov1  \
# 0                       the government should decide
# 1                                                NaN
# 2  a woman and her medical professional should de...
# 3                                                NaN
# 4                                                NaN
#
#                                            abmedgov2    abmelegl  \
# 0                                                NaN  it depends
# 1  a woman and her medical professional should de...         NaN
# 2                                                NaN  it depends
# 3  a woman and her medical professional should de...         NaN
# 4  a woman and her medical professional should de...  it depends
#
#            abmoral abnomore abpoor               abpoorw abrape absingle  \
# 0  morally opposed       no     no          always wrong    yes       no
# 1       it depends      yes     no                   NaN    yes      yes
# 2       it depends      NaN    NaN  wrong only sometimes    NaN      NaN
# 3       it depends      NaN    NaN                   NaN    NaN      NaN
# 4  morally opposed       no     no                   NaN     no       no
#
#                 abstate1              abstate2 acqntsex    actssoc  \
# 0  neither easy nor hard        make it harder      NaN  very good
# 1                   easy  stay the same as now      NaN       good
# 2              very easy        make it harder      NaN  excellent
# 3                   easy  stay the same as now      NaN  very good
# 4             Don't know  stay the same as now      NaN  excellent
#
#                                   adminconsent adults        advfront  \
# 0  r does not consent to possible data linkage      5  strongly agree
# 1  r does not consent to possible data linkage      2             NaN
# 2  r does not consent to possible data linkage      2        disagree
# 3          r consents to possible data linkage      2             NaN
# 4          r consents to possible data linkage      2             NaN
#
#                affrmact             afraidof         afterlif age  \
# 0  strongly oppose pref                never  yes, definitely  43
# 1                   NaN                never              NaN  74
# 2  strongly oppose pref                  NaN  yes, definitely  42
# 3           oppose pref                  NaN              NaN  63
# 4                   NaN  a few times a month              NaN  71
#
#           aged  agekdbrn            ancestrs arthrtis astrolgy  \
# 0          NaN       NaN  no, definitely not       no       no
# 1  a good idea      21.0                 NaN      NaN      NaN
# 2  a good idea      35.0    no, probably not       no       no
# 3  a good idea      32.0                 NaN      yes      NaN
# 4   a bad idea       NaN                 NaN      NaN      NaN
#
#                 astrosci                       atheists            attend  \
# 0  not at all scientific              somewhat negative      2-3x a month
# 1                    NaN                            NaN       once a year
# 2  not at all scientific  neither positive nor negative       once a year
# 3                    NaN                            NaN   nrly every week
# 4                    NaN                            NaN  more thn once wk
#
#                attend12              attendma                  attendpa away1  \
# 0            every week            every week  about once or twice a yr   NaN
# 1                   NaN                   NaN                       NaN   NaN
# 2  several times a week  several times a week                every week   NaN
# 3                   NaN                   NaN                       NaN   NaN
# 4                   NaN                   NaN                       NaN   NaN
#
#   away11 away2 away3 away4 away5 away6 away7  babies backpain    ballot  \
# 0    NaN   NaN   NaN   NaN   NaN   NaN   NaN     0.0       no  ballot a
# 1    NaN   NaN   NaN   NaN   NaN   NaN   NaN     0.0      NaN  ballot c
# 2    NaN   NaN   NaN   NaN   NaN   NaN   NaN     NaN       no  ballot b
# 3    NaN   NaN   NaN   NaN   NaN   NaN   NaN     0.0      yes  ballot b
# 4    NaN   NaN   NaN   NaN   NaN   NaN   NaN     0.0      NaN  ballot c
#
#               balneg             balpos            befair    betrlang  \
# 0  slightly in favor                NaN               NaN  language 1
# 1                NaN                NaN  fair all of time         NaN
# 2                NaN  strongly in favor               NaN         NaN
# 3                NaN                NaN  fair mst of time         NaN
# 4                NaN                NaN  fair mst of time         NaN
#
#            bible bigbang bigbang1 bigbang2           bird        birdb4 born  \
# 0    word of god   false      NaN      NaN            NaN           NaN  yes
# 1    word of god     NaN      NaN      NaN            NaN           NaN  yes
# 2  inspired word     NaN     true      NaN            NaN           NaN  yes
# 3  inspired word     NaN      NaN      NaN            NaN  did not have  yes
# 4  inspired word     NaN      NaN      NaN  does not have           NaN  yes
#
#     boyorgrl           breakdwn                       buddhsts  \
# 0       true                NaN  neither positive nor negative
# 1        NaN        very likely                            NaN
# 2  DONT KNOW                NaN              somewhat positive
# 3        NaN    not very likely                            NaN
# 4        NaN  not at all likely                            NaN
#
#                                              buyesop buyvalue  \
# 0  i would be neither more nor less likely to buy...      NaN
# 1                                                NaN      NaN
# 2  i would be neither more nor less likely to buy...        0
# 3  i would be less likely to buy from an employee...      NaN
# 4                                                NaN      NaN
#
#           cantrust  cappun            cat         catb4           charactr  \
# 0              NaN   favor            NaN           NaN                NaN
# 1   always trusted  oppose            NaN           NaN    somewhat likely
# 2              NaN   favor            NaN           NaN                NaN
# 3   always trusted  oppose            NaN  did not have  not at all likely
# 4  usually trusted  oppose  does not have           NaN    not very likely
#
#                chemgen childs chldidel           christns          churhpow  \
# 0  extremely dangerous      0        2      very positive  far too litl pwr
# 1                  NaN      3      NaN                NaN               NaN
# 2                  NaN      2        2  somewhat positive    too much power
# 3                  NaN      2        2                NaN               NaN
# 4                  NaN      0      NaN                NaN               NaN
#
#            class        clergvte closeto1          closeto2    closeto3  \
# 0  working class        disagree      NaN               NaN         NaN
# 1  working class             NaN        5  not close at all         NaN
# 2   middle class  strongly agree      NaN               NaN         NaN
# 3   middle class             NaN        9  not close at all           7
# 4    upper class             NaN        3  not close at all  very close
#
#   closeto4          closeto5              cntctfam              cntctfrd  \
# 0      NaN               NaN                   NaN                   NaN
# 1      NaN               NaN  several times a year           once a week
# 2      NaN               NaN                   NaN                   NaN
# 3        6  not close at all  several times a week  several times a week
# 4      NaN               NaN            less often  several times a week
#
#                            cntctkid                        cntctpar  \
# 0                               NaN                             NaN
# 1                             daily  my parents are no longer alive
# 2                               NaN                             NaN
# 3                             daily  my parents are no longer alive
# 4  i do not have any adult children  my parents are no longer alive
#
#                       cntctsib codeg coden coeduc coevwork cofund  cohort  \
# 0                          NaN   NaN   NaN    NaN      NaN    NaN  1975.0
# 1         several times a year   NaN   NaN    NaN      NaN    NaN  1944.0
# 2                          NaN   NaN   NaN    NaN      NaN    NaN  1976.0
# 3                        daily   NaN   NaN    NaN      NaN    NaN  1955.0
# 4   two to three times a month   NaN   NaN    NaN      NaN    NaN  1947.0
#
#    cohrs1  cohrs2 coind10 coisco08 cojew       colath     colcom      coldeg1  \
# 0     NaN     NaN     NaN      NaN   NaN      allowed  not fired  associate's
# 1     NaN     NaN     NaN      NaN   NaN  not allowed      fired          NaN
# 2     NaN     NaN     NaN      NaN   NaN          NaN        NaN   bachelor's
# 3     NaN     NaN     NaN      NaN   NaN          NaN        NaN          NaN
# 4     NaN     NaN     NaN      NaN   NaN  not allowed  not fired          NaN
#
#    colhomo       colmil       colmslm       colrac colsci colscinm comfort  \
# 0  allowed      allowed  yes, allowed      allowed     no      NaN   agree
# 1  allowed  not allowed   not allowed  not allowed    NaN      NaN     NaN
# 2      NaN          NaN           NaN          NaN    yes       20   agree
# 3      NaN          NaN           NaN          NaN    NaN      NaN     NaN
# 4  allowed  not allowed   not allowed  not allowed    NaN      NaN     NaN
#
#                                              company compperf comprend  \
# 0  a company whose stock is owned by outside inve...       no     good
# 1                                                NaN      NaN     good
# 2  a company whose stock is owned by the employee...      yes     good
# 3  a company whose stock is owned by the employee...      NaN     good
# 4                                                NaN      NaN     good
#
#   compuse  compwage       conarmy                      conbiz        conbus  \
# 0     yes   1 lower           NaN             some confidence           NaN
# 1     NaN       NaN  a great deal                         NaN  a great deal
# 2     yes  5 higher     only some  a great deal of confidence     only some
# 3     yes   1 lower  a great deal                         NaN     only some
# 4     NaN       NaN  a great deal                         NaN  a great deal
#
#                  conchurh      conclerg                 concong  \
# 0         some confidence           NaN         some confidence
# 1                     NaN  a great deal                     NaN
# 2  very little confidence    hardly any  very little confidence
# 3                     NaN     only some                     NaN
# 4                     NaN  a great deal                     NaN
#
#                  concourt         condemnd          condom condrift  \
# 0  very little confidence  not at all true             NaN     true
# 1                     NaN              NaN        not used      NaN
# 2         some confidence    somewhat true  used last time     true
# 3                     NaN     not too true  used last time      NaN
# 4                     NaN              NaN        not used      NaN
#
#         coneduc        conf2f        confed      confinan       coninc  \
# 0           NaN           NaN           NaN           NaN          NaN
# 1  a great deal  most of them  a great deal  a great deal   22782.5000
# 2     only some           NaN     only some    hardly any  112160.0000
# 3    hardly any  most of them    hardly any     only some  158201.8412
# 4     only some  some of them     only some  a great deal  158201.8412
#
#        conjudge      conlabor      conlegis      conmedic      conpress  \
# 0           NaN           NaN           NaN           NaN           NaN
# 1  a great deal  a great deal  a great deal  a great deal  a great deal
# 2  a great deal    hardly any    hardly any  a great deal    hardly any
# 3  a great deal     only some    hardly any    hardly any    hardly any
# 4  a great deal     only some    hardly any  a great deal    hardly any
#
#    conrinc         conschls        consci                            consent  \
# 0      NaN  some confidence           NaN  r consents to recording interview
# 1      NaN              NaN           NaN  r consents to recording interview
# 2  70100.0  some confidence  a great deal  r consents to recording interview
# 3  84120.0              NaN  a great deal  r consents to recording interview
# 4      NaN              NaN  a great deal  r consents to recording interview
#
#           contv      conwkday coocc10                 coop coother  copres10  \
# 0           NaN           NaN     NaN  friendly,interested     NaN       NaN
# 1  a great deal    5-9 people     NaN  friendly,interested     NaN       NaN
# 2     only some           NaN     NaN  friendly,interested     NaN       NaN
# 3     only some  20-49 people     NaN  friendly,interested     NaN       NaN
# 4    hardly any  20-49 people     NaN  friendly,interested     NaN       NaN
#
#    copres105plus corel  cosei10  cosei10educ  cosei10inc            courts  \
# 0            NaN   NaN      NaN          NaN         NaN  not harsh enough
# 1            NaN   NaN      NaN          NaN         NaN  not harsh enough
# 2            NaN   NaN      NaN          NaN         NaN  not harsh enough
# 3            NaN   NaN      NaN          NaN         NaN  not harsh enough
# 4            NaN   NaN      NaN          NaN         NaN  not harsh enough
#
#         cowrkhlp       cowrkint cowrkslf cowrksta crack30  \
# 0      very true      very true      NaN      NaN     NaN
# 1            NaN            NaN      NaN      NaN     NaN
# 2  somewhat true  somewhat true      NaN      NaN     NaN
# 3      very true      very true      NaN      NaN     NaN
# 4            NaN            NaN      NaN      NaN     NaN
#
#                dangoth1        dangoth2              dangoth3  \
# 0                   NaN             NaN                   NaN
# 1  not at all dangerous  very dangerous                   NaN
# 2                   NaN             NaN                   NaN
# 3  not at all dangerous               6  not at all dangerous
# 4                     5               5  not at all dangerous
#
#                dangoth4    dangoth5 dangroth dangrslf              dangslf1  \
# 0                   NaN         NaN      NaN      NaN                   NaN
# 1                   NaN         NaN      yes      yes  not at all dangerous
# 2                   NaN         NaN      NaN      NaN                   NaN
# 3  not at all dangerous  Don't know      yes      yes  not at all dangerous
# 4                   NaN         NaN      yes      yes            Don't know
#
#          dangslf2              dangslf3              dangslf4    dangslf5  \
# 0             NaN                   NaN                   NaN         NaN
# 1  very dangerous                   NaN                   NaN         NaN
# 2             NaN                   NaN                   NaN         NaN
# 3               6  not at all dangerous  not at all dangerous  Don't know
# 4      Don't know                     5                   NaN         NaN
#
#    dateintv       decmoney       dectreat defpensn          degree  \
# 0       907            NaN            NaN      yes  junior college
# 1       426  not very able      very able      NaN     high school
# 2       910            NaN            NaN       no        bachelor
# 3       425  somewhat able  not very able      yes        bachelor
# 4       718      very able      very able      NaN        graduate
#
#            demands             denkid             denom           denom16  \
# 0              NaN  baptist, dk which   no denomination  baptist-dk which
# 1  yes, but seldom                NaN               NaN               NaN
# 2              NaN                NaN               NaN               NaN
# 3        no, never                NaN  united methodist               NaN
# 4   yes, sometimes                NaN               NaN               NaN
#
#   depress deptperf diabetes diagnosd    difrel                    dinefrds  \
# 0      no       no       no      NaN  disagree                         NaN
# 1     NaN      NaN      NaN       no       NaN                       never
# 2      no       no       no      NaN     agree                         NaN
# 3     yes      NaN       no      yes       NaN        several times a year
# 4     NaN      NaN      NaN       no       NaN  two to three times a month
#
#                 dipged          discaff           discaffm           discaffw  \
# 0  high school diploma  somewhat likely  somewhat unlikely                NaN
# 1                  ged  not very likely                NaN                NaN
# 2  high school diploma              NaN  somewhat unlikely                NaN
# 3  high school diploma              NaN                NaN  somewhat unlikely
# 4  high school diploma  not very likely                NaN                NaN
#
#                 disrspct          divlaw divorce  \
# 0    a few times a month  more difficult     NaN
# 1                  never             NaN     NaN
# 2                    NaN  more difficult      no
# 3                    NaN          easier      no
# 4  less than once a year             NaN     NaN
#
#                                    dofirst            dog dogb4  \
# 0                                      NaN            NaN   NaN
# 1      talk to family and friends about it            NaN   NaN
# 2                                      NaN            NaN   NaN
# 3  go to a general medical doctor for help            NaN   had
# 4  go to a general medical doctor for help  does not have   NaN
#
#                dwelling                      dwellpre           dwelown  \
# 0  detached 1-fam house  detached single family house         pays rent
# 1  detached 1-fam house  detached single family house               NaN
# 2  detached 1-fam house  detached single family house  own or is buying
# 3  detached 1-fam house  detached single family house  own or is buying
# 4  detached 1-fam house  detached single family house               NaN
#
#              dwelown16 earnrs          earthsun  educ  \
# 0  owned or was buying    1.0  earth around sun  14.0
# 1                  NaN    1.0               NaN  10.0
# 2  owned or was buying    2.0  earth around sun  16.0
# 3  owned or was buying    2.0               NaN  16.0
# 4                  NaN    1.0               NaN  18.0
#
#                      egomeans electron  emailhr  emailmin   emoprobs empinput  \
# 0                    disagree     true     25.0       0.0     rarely       no
# 1                         NaN      NaN      NaN       NaN     rarely      NaN
# 2  neither agree nor disagree    false     20.0       0.0  sometimes       no
# 3                         NaN      NaN      7.0       0.0     rarely      yes
# 4                         NaN      NaN      NaN       NaN     rarely      NaN
#
#   emptrain                    endsmeet          eqwlth esop  \
# 0      yes                         NaN             NaN  NaN
# 1      NaN  neither easy nor difficult  no govt action  NaN
# 2      yes                         NaN               3   no
# 3       no                   very easy               5  NaN
# 4      NaN                   very easy               6  NaN
#
#                                              esopnot      eth1  \
# 0  i would definitely take the job with the esop ...   germany
# 1                                                NaN     italy
# 2  i would definitely take the job without the es...     italy
# 3  i would probably take the job with the esop (e...    france
# 4                                                NaN  scotland
#
#                eth2              eth3            ethnic           ethnum  \
# 0          scotland  UNCODEABLE & IAP  UNCODEABLE & IAP  cannot choose 1
# 1  UNCODEABLE & IAP  UNCODEABLE & IAP             italy          names 1
# 2     other spanish  UNCODEABLE & IAP  UNCODEABLE & IAP  cannot choose 1
# 3   england & wales           ireland           ireland  chooses 1 of 2+
# 4           ireland  UNCODEABLE & IAP          scotland  chooses 1 of 2+
#
#   evcrack evidu evolved evolved2 evpaidsx evstray evwork  \
# 0     NaN   NaN   false      NaN      NaN     NaN    NaN
# 1      no    no     NaN      NaN       no      no    yes
# 2      no    no    true      NaN       no      no    NaN
# 3      no    no     NaN      NaN       no     yes    NaN
# 4      no    no     NaN      NaN       no      no    yes
#
#                     expdesgn                exptext extr2017 extrapay  \
# 0                  DONT KNOW                    NaN      yes      yes
# 1                        NaN                    NaN      NaN      NaN
# 2  500 get the drug 500 dont  correct control group      yes      yes
# 3                        NaN                    NaN      NaN       no
# 4                        NaN                    NaN      NaN      NaN
#
#     extraval extrayr            fair                        fairearn  \
# 0  DONT KNOW    2018             NaN  somewhat less than you deserve
# 1        NaN     NaN  take advantage                             NaN
# 2      10000     NaN            fair  somewhat more than you deserve
# 3        NaN     NaN            fair    about as much as you deserve
# 4        NaN     NaN            fair                             NaN
#
#             famdif16            famgen            family16       fammhneg  \
# 0                NaN             1 gen     mother & father            NaN
# 1                NaN  2 gens, children     mother & father       somewhat
# 2  divorce,separated  2 gens, children  father & stpmother            NaN
# 3                NaN             1 gen     mother & father  not very much
# 4                NaN             1 gen     mother & father     not at all
#
#     fampress    famvswk         famwkoff           fatalism fatigue fear  \
# 0        NaN     rarely    somewhat hard  strongly disagree    mild  yes
# 1  no, never        NaN              NaN                NaN    none   no
# 2        NaN  sometimes  not at all hard           disagree  severe  NaN
# 3  no, never     rarely     not too hard                NaN    mild  NaN
# 4  no, never        NaN              NaN                NaN    none   no
#
#            fechld feelevel         feelrel     feeused     fefam fehire  \
# 0  strongly agree     $75+  very religious  yes, money  disagree    NaN
# 1             NaN       25             NaN  yes, money       NaN    NaN
# 2  strongly agree     $75+  not rel or non  yes, money  disagree    NaN
# 3           agree       25             NaN  yes, money  disagree  agree
# 4             NaN     $75+             NaN  yes, money       NaN    NaN
#
#            fejobaff     fepol           fepresch     finalter  \
# 0  strongly against     agree  strongly disagree       better
# 1               NaN       NaN                NaN        worse
# 2           against  disagree           disagree       better
# 3               NaN  disagree           disagree       better
# 4               NaN       NaN                NaN  stayed same
#
#              finrela        firstyou           fish        fishb4  \
# 0      below average             NaN            NaN           NaN
# 1      below average           agree            NaN           NaN
# 2      above average             NaN            NaN           NaN
# 3      above average  strongly agree            NaN  did not have
# 4  far above average  strongly agree  does not have           NaN
#
#             form  formwt       fringeok frndsex fucitzn      fund  \
# 0   standard <x>       1  somewhat true     NaN     NaN  moderate
# 1  alternate <y>       1            NaN     NaN     NaN  moderate
# 2   standard <x>       1      very true     NaN     NaN   liberal
# 3  alternate <y>       1   not too true     NaN     NaN   liberal
# 4  alternate <y>       1            NaN     NaN     NaN  moderate
#
#            fund16 gender1 gender10 gender11 gender12 gender2 gender3 gender4  \
# 0  fundamentalist    male      NaN      NaN      NaN  female    male    male
# 1        moderate  female      NaN      NaN      NaN  female     NaN     NaN
# 2        moderate    male      NaN      NaN      NaN  female    male  female
# 3        moderate    male      NaN      NaN      NaN  female     NaN     NaN
# 4        moderate    male      NaN      NaN      NaN  female     NaN     NaN
#
#   gender5 gender6 gender7 gender8 gender9 geneabrt2             genegen  \
# 0    male     NaN     NaN     NaN     NaN        no  somewhat dangerous
# 1     NaN     NaN     NaN     NaN     NaN        no                 NaN
# 2     NaN     NaN     NaN     NaN     NaN       NaN                 NaN
# 3     NaN     NaN     NaN     NaN     NaN       NaN                 NaN
# 4     NaN     NaN     NaN     NaN     NaN        no                 NaN
#
#       genegoo2 geneself2           genetics        genetst1   getahead  \
# 0  good > harm        no                NaN   not very much  hard work
# 1  harm > good        no    somewhat likely  nothing at all  hard work
# 2          NaN       NaN                NaN             NaN        NaN
# 3          NaN       NaN    somewhat likely             NaN        NaN
# 4  good > harm        no  not at all likely   not very much  hard work
#
#             goat        goatb4                 god  \
# 0            NaN           NaN     know god exists
# 1            NaN           NaN     know god exists
# 2            NaN           NaN  believe but doubts
# 3            NaN  did not have     know god exists
# 4  does not have           NaN     know god exists
#
#                       godchnge  godmeans           godswill goodlife  \
# 0  believe now, didn't used to  disagree                NaN      NaN
# 1                          NaN       NaN    somewhat likely    agree
# 2   don't believe now, used to  disagree                NaN    agree
# 3                          NaN       NaN  not at all likely  neither
# 4                          NaN       NaN  not at all likely    agree
#
#             goveqinc   govlazy        govvsrel    granborn      grass gunlaw  \
# 0                NaN       NaN  strongly agree  all in u.s        NaN  favor
# 1  strongly disagree     agree             NaN           4  not legal  favor
# 2                NaN       NaN  strongly agree           2      legal    NaN
# 3           disagree  disagree             NaN  all in u.s  not legal    NaN
# 4           disagree     agree             NaN           2  not legal  favor
#
#   handmove hapcohab      hapmar         happy      hapunhap       haveinfo  \
# 0       no      NaN         NaN  pretty happy  fairly happy  somewhat true
# 1      NaN      NaN         NaN    very happy           NaN            NaN
# 2       no      NaN  very happy    very happy    very happy  somewhat true
# 3      yes      NaN  very happy    very happy           NaN      very true
# 4      NaN      NaN         NaN  pretty happy           NaN            NaN
#
#       health    health1 healthissp           heaven     hefinfo height  \
# 0       good       good       good  yes, definitely  4th person     73
# 1  excellent        NaN  very good              NaN  1st person    NaN
# 2        NaN  very good  very good    yes, probably  1st person     68
# 3        NaN  excellent  excellent              NaN  1st person     68
# 4  excellent        NaN  excellent              NaN  1st person    NaN
#
#               hell               helpblk                    helpfrds  helpful  \
# 0  yes, definitely                   NaN                         NaN      NaN
# 1              NaN        govt help blks                       agree  helpful
# 2    yes, probably       agree with both                         NaN  helpful
# 3              NaN       agree with both  neither agree nor disagree  helpful
# 4              NaN  no special treatment                       agree  helpful
#
#               helpnot        helpoth         helppoor         helpsick  \
# 0                 NaN            NaN              NaN              NaN
# 1     agree with both  2nd important  agree with both  agree with both
# 2  govt does too much  3rd important                4  agree with both
# 3                   4  3rd important                2                2
# 4        govt do more  2nd important                4  agree with both
#
#          hhrace                  hhtype                      hhtype1  \
# 0  other, mixed      4+adlts,0mar,0kids          unsure, no children
# 1         white  2adlts,ntmar,rel,0kids      other fam., no children
# 2  other, mixed       2adlts,mar,1+kids    married couple w children
# 3         white        2adlts,mar,0kids  married couple, no children
# 4         white      2adlts,dkmar,0kids          unsure, no children
#
#                           hindus      hispanic hivtest hivtest1 hivtest2  \
# 0  neither positive nor negative  not hispanic     NaN      NaN      NaN
# 1                            NaN  not hispanic      no      NaN      NaN
# 2              somewhat positive       chilean      no      NaN      NaN
# 3                            NaN  not hispanic      no      NaN      NaN
# 4                            NaN  not hispanic      no      NaN      NaN
#
#               hlpadvce              hlpdown       hlpequip  \
# 0                  NaN                  NaN  somewhat true
# 1  close family member  close family member            NaN
# 2                  NaN                  NaN      very true
# 3         close friend         close friend  somewhat true
# 4               no one               no one            NaN
#
#                hlphome                                 hlpjob  \
# 0                  NaN                                    NaN
# 1  close family member              no person or organization
# 2                  NaN                                    NaN
# 3  close family member                    other organizations
# 4         someone else  non-profit or religious organizations
#
#                hlploan                               hlppaper  \
# 0                  NaN                                    NaN
# 1      public services                        public services
# 2                  NaN                                    NaN
# 3    private companies                      private companies
# 4  other organizations  non-profit or religious organizations
#
#                     hlpresde              hlpsick  \
# 0                        NaN                  NaN
# 1  no person or organization  close family member
# 2                        NaN                  NaN
# 3          private companies  close family member
# 4                 Don't know               no one
#
#                           hlpsickr             hlpsococ hlthdays   hlthmntl  \
# 0                              NaN                  NaN        0  very good
# 1  family members or close friends  close family member      NaN  very good
# 2                              NaN                  NaN        0  very good
# 3              other organizations         close friend        0  excellent
# 4  family members or close friends         close friend      NaN  very good
#
#     hlthphys hlthstrt           homosex          homosex1  hompop  \
# 0       good      NaN      always wrong      always wrong       5
# 1  very good     good  not wrong at all               NaN       2
# 2       good      NaN               NaN  not wrong at all       4
# 3  excellent     good               NaN               NaN       2
# 4  excellent     good  not wrong at all               NaN       2
#
#            horse       horseb4 hotcore hrs1  hrs2 hrsrelax hsbio hschem  \
# 0            NaN           NaN    true  NaN  41.0        3   yes    yes
# 1            NaN           NaN     NaN  NaN   NaN      NaN   NaN    NaN
# 2            NaN           NaN    true   40   NaN        3   yes    yes
# 3            NaN  did not have     NaN   40   NaN        7   NaN    NaN
# 4  does not have           NaN     NaN  NaN   NaN      NaN   NaN    NaN
#
#                                      hsmath hsphys huadd huaddwhy  \
# 0  trigonometry linear programming analysis     no   yes      NaN
# 1                                       NaN    NaN   yes      NaN
# 2                              pre-calculus     no   yes      NaN
# 3                                       NaN    NaN   yes      NaN
# 4                                       NaN    NaN   yes      NaN
#
#                      hubbywrk    huclean     hunt          hunt1 hurtatwk  \
# 0  neither agree nor disagree  NO ANSWER  neither  neither hunts        0
# 1                         NaN      clean  neither  neither hunts      NaN
# 2           strongly disagree  NO ANSWER      NaN            NaN        0
# 3                         NaN      clean      NaN            NaN        0
# 4                         NaN  NO ANSWER  neither  neither hunts      NaN
#
#              hurtoth           hurtself hvylift hyperten  id idu30 if12who  \
# 0                NaN                NaN      no      yes   1   NaN     NaN
# 1    not very likely        very likely     NaN      NaN   2   NaN     NaN
# 2                NaN                NaN      no      yes   3   NaN     NaN
# 3    not very likely    somewhat likely     yes      yes   4   NaN     NaN
# 4  not likely at all  not likely at all     NaN      NaN   5   NaN     NaN
#
#   if16who         imbalnce           imprvown           imprvtrt    incgap  \
# 0     NaN              NaN                NaN                NaN       NaN
# 1     NaN  not very likely        very likely  not likely at all   neither
# 2     NaN              NaN                NaN                NaN       NaN
# 3     NaN      very likely  not likely at all        very likely     agree
# 4     NaN        DONT KNOW    somewhat likely  not likely at all  disagree
#
#              incom16          income            income16             incuspop  \
# 0      below average             NaN                 NaN              average
# 1  far below average  $25000 or more     $30000 to 34999              average
# 2      above average  $25000 or more  $150000 to $169999              average
# 3      above average             NaN     $170000 or over              average
# 4      below average             NaN     $170000 or over  higher than average
#
#   indperf                                            indus10  \
# 0     yes                                employment services
# 1     NaN                                     grocery stores
# 2     yes                  wired telecommunications carriers
# 3     NaN                                          hospitals
# 4     NaN  electronic component and product manufacturing...
#
#               indusgen  intage                   intcntct          intecon  \
# 0  extremely dangerous      68                        NaN  very interested
# 1                  NaN      62  none or almost none of it              NaN
# 2                  NaN      68                        NaN  very interested
# 3                  NaN      62                 most of it              NaN
# 4                  NaN      68    all or almost all of it              NaN
#
#                  inteduc         intenvir intethn                intfarm  \
# 0  moderately interested  very interested   white  moderately interested
# 1                    NaN              NaN   white                    NaN
# 2        very interested  very interested   white  moderately interested
# 3                    NaN              NaN   white                    NaN
# 4                    NaN              NaN   white                    NaN
#
#         inthisp  intid                intintl     intlblks     intlhsps  \
# 0           NaN    125  moderately interested            4            4
# 1  not hispanic     32                    NaN          NaN          NaN
# 2           NaN    125  moderately interested  intelligent  intelligent
# 3  not hispanic     32                    NaN            5            5
# 4           NaN    125                    NaN          NaN          NaN
#
#       intlwhts           intmed                 intmil   intrace1   intrace2  \
# 0            4  very interested  moderately interested  No Answer  No Answer
# 1          NaN              NaN                    NaN      white        NaN
# 2  intelligent  very interested  moderately interested  No Answer  No Answer
# 3            5              NaN                    NaN      white        NaN
# 4          NaN              NaN                    NaN  No Answer  No Answer
#
#     intrace3           intsci  intsex               intspace  \
# 0  No Answer  very interested  female  moderately interested
# 1        NaN              NaN  female                    NaN
# 2  No Answer  very interested  female  moderately interested
# 3        NaN              NaN  female                    NaN
# 4  No Answer              NaN  female                    NaN
#
#                  inttech  intyrs  \
# 0  moderately interested    23.0
# 1                    NaN    21.0
# 2        very interested    23.0
# 3                    NaN    21.0
# 4                    NaN    23.0
#
#                                               isco08  isco88      issp  jew  \
# 0                personnel and careers professionals  4190.0  did issp  NaN
# 1                                       hand packers  9322.0  did issp  NaN
# 2                     computer network professionals  2131.0  did issp  NaN
# 3  medical imaging and therapeutic equipment tech...  3133.0  did issp  NaN
# 4                            human resource managers  1232.0  did issp  NaN
#
#   jew16               jews        jobfind  \
# 0   NaN  somewhat negative      very easy
# 1   NaN                NaN            NaN
# 2   NaN  somewhat positive  somewhat easy
# 3   NaN                NaN       not easy
# 4   NaN                NaN            NaN
#
#                               jobfind1     joblose       jobsecok  \
# 0        very easy to find similar job  not likely  somewhat true
# 1                                  NaN         NaN            NaN
# 2    somewhat easy to find similar job  not likely  somewhat true
# 3  not easy at all to find similar job  not likely      very true
# 4                                  NaN         NaN            NaN
#
#           kidpars kidsinhh          kidssol               knowschd  \
# 0             NaN      yes              NaN        4 weeks or more
# 1  strongly agree       no      much better                    NaN
# 2             NaN      yes  somewhat better        4 weeks or more
# 3           agree      yes   about the same  between 3 and 4 weeks
# 4  strongly agree      yes   somewhat worse                    NaN
#
#          knowwhat               knwbus            knwclenr  \
# 0  strongly agree                  NaN                 NaN
# 1             NaN               no one              no one
# 2           agree                  NaN                 NaN
# 3  strongly agree  someone else i know  family or relative
# 4             NaN               no one              no one
#
#                knwcop            knwcuttr       knwexec             knwhrman  \
# 0                 NaN                 NaN           NaN                  NaN
# 1              no one              no one        no one               no one
# 2                 NaN                 NaN           NaN                  NaN
# 3  family or relative  family or relative        no one  someone else i know
# 4        close friend              no one  close friend         close friend
#
#               knwlawyr            knwmchnc  knwmw1  knwmw2  knwmw3  knwmw4  \
# 0                  NaN                 NaN     NaN     NaN     NaN     NaN
# 1  someone else i know              no one    male  female     NaN     NaN
# 2                  NaN                 NaN     NaN     NaN     NaN     NaN
# 3   family or relative  family or relative    male    male  female  female
# 4         close friend              no one  female    male    male     NaN
#
#    knwmw5            knwnurse            knwtcher laidoff lasers  \
# 0     NaN                 NaN                 NaN      no  false
# 1     NaN              no one              no one     NaN    NaN
# 2     NaN                 NaN                 NaN      no  false
# 3  female        close friend  family or relative      no    NaN
# 4     NaN  family or relative  family or relative     NaN    NaN
#
#          learnnew letdie1                   letin1a      libath      libcom  \
# 0  strongly agree      no  remain the same as it is  not remove  not remove
# 1             NaN     NaN                       NaN  not remove  not remove
# 2           agree     yes          reduced a little         NaN         NaN
# 3  strongly agree      no        increased a little         NaN         NaN
# 4             NaN     NaN                       NaN  not remove  not remove
#
#       libhomo      libmil     libmslm      librac      life  \
# 0  not remove  not remove  not remove  not remove   routine
# 1  not remove  not remove  not remove  not remove  exciting
# 2         NaN         NaN         NaN         NaN       NaN
# 3         NaN         NaN         NaN         NaN       NaN
# 4  not remove  not remove  not remove  not remove   routine
#
#                lifein5 lifenow                  liveblks lngthinv  \
# 0                    9       7  neither favor nor oppose      136
# 1                  NaN     NaN                       NaN      153
# 2  best possible state       8                     favor       90
# 3                    8       8  neither favor nor oppose      192
# 4                  NaN     NaN                       NaN      111
#
#       localnum lonely1 lonely2 lonely3           madeg           madenkid  \
# 0          1-9     NaN     NaN     NaN     high school  baptist, dk which
# 1          NaN   never   never   never  lt high school                NaN
# 2      100-499     NaN     NaN     NaN        bachelor                NaN
# 3  1,000-1,999  rarely  rarely  rarely     high school                NaN
# 4          NaN  rarely   never   never     high school                NaN
#
#   maeduc                                       maind10  \
# 0     12                               clothing stores
# 1      8  textile product mills, except carpet and rug
# 2     16                banking and related activities
# 3     12                                Not applicable
# 4     12              elementary and secondary schools
#
#                    maisco08  maisco88                   major1  \
# 0     shop sales assistants    5220.0    communications/speech
# 1  sewing machine operators    8263.0                      NaN
# 2     general office clerks    4110.0              electronics
# 3                       NaN       NaN  business administration
# 4        child care workers    5131.0  business administration
#
#              major2               majorcol  makefrnd  \
# 0               NaN  communications/speech  disagree
# 1               NaN                    NaN       NaN
# 2               NaN            electronics     agree
# 3  computer science                    NaN       NaN
# 4               NaN                    NaN       NaN
#
#                          maleornt    manvsemp                   maocc10  \
# 0  r sexual orientation uncertain   very good       retail salespersons
# 1                             NaN         NaN  sewing machine operators
# 2                             NaN  quite good    office clerks, general
# 3                             NaN  quite good                       NaN
# 4         r is not homosexual/gay         NaN         childcare workers
#
#    mapres10  mapres105plus     mar1 mar11 mar12      mar2           mar3  \
# 0      31.0           18.0      NaN   NaN   NaN       NaN            NaN
# 1      32.0           22.0  married   NaN   NaN  divorced            NaN
# 2      32.0           26.0      NaN   NaN   NaN       NaN  never married
# 3       NaN            NaN  married   NaN   NaN   married            NaN
# 4      35.0           28.0  married   NaN   NaN   married            NaN
#
#             mar4 mar5 mar6 mar7 mar8 mar9                  marasian  \
# 0  never married  NaN  NaN  NaN  NaN  NaN  neither favor nor oppose
# 1            NaN  NaN  NaN  NaN  NaN  NaN                       NaN
# 2  never married  NaN  NaN  NaN  NaN  NaN            strongly favor
# 3            NaN  NaN  NaN  NaN  NaN  NaN  neither favor nor oppose
# 4            NaN  NaN  NaN  NaN  NaN  NaN                       NaN
#
#                      marblk                              marcohab    marelkid  \
# 0                    oppose  not married, no cohabitating partner  protestant
# 1                       NaN  not married, no cohabitating partner         NaN
# 2            strongly favor                               married    catholic
# 3  neither favor nor oppose                               married         NaN
# 4                       NaN  not married, no cohabitating partner         NaN
#
#                     marhisp            marhomo        marital  \
# 0  neither favor nor oppose  strongly disagree  never married
# 1                       NaN              agree      separated
# 2                     favor                NaN        married
# 3  neither favor nor oppose                NaN        married
# 4                       NaN  strongly disagree       divorced
#
#                               martype                    marwht  masei10  \
# 0                                 NaN  neither favor nor oppose     39.7
# 1                                 NaN                       NaN     13.2
# 2  marriage between a man and a woman                     favor     35.8
# 3  marriage between a man and a woman  neither favor nor oppose      NaN
# 4                                 NaN                       NaN     21.8
#
#    masei10educ  masei10inc matesex mawrkgrw      mawrkslf mcsds1 mcsds2  \
# 0         55.9        30.9     NaN      yes  someone else    NaN    NaN
# 1         16.5         5.5     NaN      yes  someone else   true  false
# 2         56.1        22.8     yes      yes  someone else    NaN    NaN
# 3          NaN         NaN     NaN       no           NaN  false   true
# 4         45.4         6.9     NaN      yes  someone else   true   true
#
#   mcsds3 mcsds4 mcsds5 mcsds6 mcsds7 meddoc mentldoc mentlhos  \
# 0    NaN    NaN    NaN    NaN    NaN    NaN      NaN      NaN
# 1   true  false  false  false  false    yes      yes       no
# 2    NaN    NaN    NaN    NaN    NaN    NaN      NaN      NaN
# 3   true  false  false   true  false    yes      yes      yes
# 4  false  false   true   true  false    yes       no       no
#
#           mentlill mentloth                    meovrwrk mhdiagno  \
# ...
#          smammal     smammalb4        socbar          socfrend  \
# 0            NaN           NaN  once a month  sev times a mnth
# 1            NaN           NaN           NaN               NaN
# 2            NaN           NaN   once a year      once a month
# 3            NaN  did not have   once a year      once a month
# 4  does not have           NaN           NaN               NaN
#
#            socommun            socrel  solarrev  spaneng spanint  spanking  \
# 0             never  sev times a year  one year  english     NaN     agree
# 1               NaN               NaN       NaN  english     NaN       NaN
# 2  sev times a mnth      almost daily  one year  english     NaN     agree
# 3             never      almost daily       NaN  english     NaN  disagree
# 4               NaN               NaN       NaN  english     NaN       NaN
#
#   spanself           spdeg             spden speduc spevwork spfalook  \
# 0      NaN             iap               NaN    iap      NaN      iap
# 1      NaN             iap               NaN    iap      NaN      iap
# 2      NaN  junior college               NaN     14      NaN      iap
# 3      NaN  junior college  united methodist     14      NaN      iap
# 4      NaN             iap               NaN    iap      NaN      iap
#
#      spfund sphealer sphrs1  sphrs2  \
# 0       NaN      NaN    NaN     NaN
# 1       NaN      yes    NaN     NaN
# 2  moderate      NaN   40.0     NaN
# 3   liberal       no   40.0     NaN
# 4       NaN       no    NaN     NaN
#
#                                      spind10  \
# 0                             Not applicable
# 1                             Not applicable
# 2  pharmaceutical and medicine manufacturing
# 3                                  hospitals
# 4                             Not applicable
#
#                                             spisco08  spisco88 spjew   spkath  \
# 0                                                NaN       NaN   NaN  allowed
# 1                                                NaN       NaN   NaN  allowed
# 2                           agricultural technicians    3212.0   NaN      NaN
# 3  medical imaging and therapeutic equipment tech...    3133.0   NaN      NaN
# 4                                                NaN       NaN   NaN  allowed
#
#     spkcom  spkhomo spklang       spkmil       spkmslm   spkrac splive  \
# 0  allowed  allowed    well      allowed  yes, allowed  allowed    iap
# 1  allowed  allowed     NaN  not allowed  yes, allowed  allowed    iap
# 2      NaN      NaN     NaN          NaN           NaN      NaN    iap
# 3      NaN      NaN     NaN          NaN           NaN      NaN    iap
# 4  allowed  allowed     NaN      allowed  yes, allowed  allowed    iap
#
#                                             spocc10 spother  sppres10  \
# 0                                               NaN     NaN       NaN
# 1                                               NaN     NaN       NaN
# 2         agricultural and food science technicians     NaN      45.0
# 3  diagnostic related technologists and technicians     NaN      59.0
# 4                                               NaN     NaN       NaN
#
#    sppres105plus       sprel          sprtprsn  spsei10  spsei10educ  \
# 0            NaN         NaN    very spiritual      NaN          NaN
# 1            NaN         NaN    very spiritual      NaN          NaN
# 2           50.0    catholic  modeate spirtual     44.5         55.6
# 3           79.0  protestant  modeate spirtual     69.3         86.7
# 4            NaN         NaN    very spiritual      NaN          NaN
#
#    spsei10inc      spvtrfair spwksup      spwrkslf          spwrksta  \
# 0         NaN      very true     NaN           NaN               NaN
# 1         NaN            NaN     NaN           NaN               NaN
# 2        42.5  somewhat true      no  someone else  working fulltime
# 3        68.4      very true      no  someone else  working fulltime
# 4         NaN            NaN     NaN           NaN               NaN
#
#           srcbelt stockops stockval     stress   stress12         stresses  \
# 0  suburb, 13-100       no      NaN     always  No answer              NaN
# 1  suburb, 13-100      NaN      NaN    NO ISSP        NaN      very likely
# 2  suburb, 13-100       no       10  sometimes         no              NaN
# 3  suburb, 13-100      NaN      NaN      often        yes  somewhat likely
# 4  suburb, 13-100      NaN      NaN    NO ISSP        NaN  somewhat likely
#
#   strredpg suicide1 suicide2 suicide3 suicide4       supcares  \
# 0       no      yes      yes      yes      yes  somewhat true
# 1      NaN      NaN      NaN      NaN      NaN            NaN
# 2      yes       no       no       no       no  somewhat true
# 3      yes      yes       no       no       no      very true
# 4      NaN      NaN      NaN      NaN      NaN            NaN
#
#            supervis        suphelp       tax        teamsafe  teens  \
# 0  doesnt supervise  somewhat true  too high  strongly agree    0.0
# 1           NO ISSP            NaN  too high             NaN    0.0
# 2        supervises   not too true       NaN           agree    NaN
# 3        supervises      very true       NaN  strongly agree    0.0
# 4           NO ISSP            NaN  too high             NaN    0.0
#
#             teensex              tempgen                      theism  \
# 0  almst always wrg  extremely dangerous              strongly agree
# 1               NaN                  NaN                         NaN
# 2      always wrong                  NaN  neither agree nor disagree
# 3      always wrong                  NaN                         NaN
# 4               NaN                  NaN                         NaN
#
#          thnkself               threaten tlkclrgy tlkfam   toofast   toofewwk  \
# 0             NaN                  never      NaN    NaN  disagree      often
# 1  most important                  never      yes    yes       NaN        NaN
# 2  most important                    NaN      NaN    NaN  disagree      often
# 3   2nd important                    NaN      yes    yes       NaN  sometimes
# 4   3rd important  less than once a year       no    NaN       NaN        NaN
#
#   trbigbus trcourts   trdunion                 trust  trustman  \
# 0      NaN      NaN  DONT KNOW                   NaN  disagree
# 1        7        7        NaN             can trust       NaN
# 2      NaN      NaN   disagree  can't be too careful     agree
# 3        6        8   disagree             can trust     agree
# 4        8        8        NaN             can trust       NaN
#
#           trustsci           trynewjb  tvhours unemp unhappy            union  \
# 0   strongly agree    somewhat likely      3.0   NaN     NaN              NaN
# 1              NaN                NaN      NaN    no   never        r belongs
# 2  strong disagree  not at all likely      1.0    no     NaN  neither belongs
# 3              NaN  not at all likely      1.0    no  rarely   spouse belongs
# 4              NaN                NaN      NaN    no   never  neither belongs
#
#                       union1 unrelat         upsdowns   upset uscitzn  \
# 0                        NaN     NaN              NaN     NaN     NaN
# 1                  r belongs     0.0      very likely   never     NaN
# 2            neither belongs     0.0              NaN     NaN     NaN
# 3  spouse or partner belongs     0.0  not very likely  rarely     NaN
# 4            neither belongs     NaN  somewhat likely   never     NaN
#
#       usedup  usetech usewww uswary  version         vetyears  \
# 0  sometimes    100.0    NaN    yes        1             none
# 1        NaN      NaN    NaN    NaN        3             none
# 2      often    100.0    NaN    NaN        2             none
# 3  sometimes     70.0    NaN    NaN        2             none
# 4        NaN      NaN    NaN    NaN        3  more than 4 yrs
#
#               vigfrnd              viggrp         viglabel  \
# 0                 NaN                 NaN              NaN
# 1  definitely willing  definitely willing      very likely
# 2                 NaN                 NaN              NaN
# 3    probably willing    probably willing  somewhat likely
# 4  definitely willing    probably willing              NaN
#
#                vigmar            vignei              vigsoc  vigversn  \
# 0                 NaN               NaN                 NaN       NaN
# 1  definitely willing  probably willing    probably willing       6.0
# 2                 NaN               NaN                 NaN       NaN
# 3  probably unwilling  probably willing    probably willing      44.0
# 4    probably willing  probably willing  definitely willing      85.0
#
#               vigwork viruses     visitors  visnhist  vissci vistholy  viszoo  \
# 0                 NaN    true  no visitors       1.0     0.0    never     2.0
# 1  definitely willing     NaN  no visitors       NaN     NaN      NaN     NaN
# 2                 NaN    true  no visitors       3.0     3.0    never     2.0
# 3  probably unwilling     NaN  no visitors       NaN     NaN      NaN     NaN
# 4    probably willing     NaN  no visitors       NaN     NaN      NaN     NaN
#
#   vote12 vote16  vpsu  vstrat             watergen           waypaid  \
# 0  voted  voted     1    3301  extremely dangerous  paid by the hour
# 1  voted  voted     1    3301                  NaN               NaN
# 2  voted  voted     1    3301                  NaN  paid by the hour
# 3  voted  voted     1    3301                  NaN          salaried
# 4  voted  voted     1    3301                  NaN               NaN
#
#             wayraise                    wealth webmob  weekswrk weight where1  \
# 0                NaN                 DONT KNOW    NaN      52.0    235    NaN
# 1    not very likely                       NaN    NaN       0.0    NaN    NaN
# 2                NaN      $250,000 to $500,000    NaN      52.0    225    NaN
# 3  not at all likely  $1 million to $2 million    NaN      52.0    170    NaN
# 4    somewhat likely                       NaN    NaN       0.0    NaN    NaN
#
#   where11 where2 where3 where4 where5 where6 where7 whoelse1 whoelse2  \
# 0     NaN    NaN    NaN    NaN    NaN    NaN    NaN       no       no
# 1     NaN    NaN    NaN    NaN    NaN    NaN    NaN       no       no
# 2     NaN    NaN    NaN    NaN    NaN    NaN    NaN       no       no
# 3     NaN    NaN    NaN    NaN    NaN    NaN    NaN       no       no
# 4     NaN    NaN    NaN    NaN    NaN    NaN    NaN       no       no
#
#   whoelse3 whoelse4 whoelse5 whoelse6                               whynopet  \
# 0       no       no       no      yes                                    NaN
# 1       no       no       no      yes                          too expensive
# 2       no       no       no      yes                                    NaN
# 3      yes       no       no       no  too much time or work to care for pet
# 4       no       no       no      yes                                    NaN
#
#                        whywkhme widowed wkageism   wkdecide       wkfreedm  \
# 0  worker wants to work at home     NaN       no  sometimes  somewhat true
# 1                           NaN      no      NaN        NaN            NaN
# 2  worker wants to work at home      no       no  sometimes  somewhat true
# 3                     NO ANSWER      no       no      often      very true
# 4                           NaN      no      NaN        NaN            NaN
#
#   wkharoth wkharsex wkpraise wkracism wksexism        wksmooth wksub wksub1  \
# 0       no       no    maybe       no       no           agree   yes    yes
# 1      NaN      NaN      NaN      NaN      NaN             NaN   NaN    NaN
# 2       no       no      yes       no       no           agree   yes    yes
# 3       no       no      yes       no      yes  strongly agree   yes    yes
# 4      NaN      NaN      NaN      NaN      NaN             NaN   NaN    NaN
#
#   wksubs wksubs1 wksup wksup1 wksups wksups1    wkvsfam wlthblks wlthhsps  \
# 0    yes     yes   yes    yes     no      no     rarely        4        5
# 1    NaN     NaN   NaN    NaN    NaN     NaN        NaN      NaN      NaN
# 2    yes     yes   yes    yes     no      no  sometimes        4        4
# 3    yes     yes   yes    yes     no      no     rarely        5      NaN
# 4    NaN     NaN   NaN    NaN    NaN     NaN        NaN      NaN      NaN
#
#   wlthwhts    worda    wordb      wordc    wordd    worde    wordf      wordg  \
# 0        4  correct  correct    correct  correct  correct  correct  incorrect
# 1      NaN      NaN      NaN        NaN      NaN      NaN      NaN        NaN
# 2        4  correct  correct  incorrect  correct  correct  correct  incorrect
# 3        4  correct  correct  incorrect  correct  correct  correct    correct
# 4      NaN      NaN      NaN        NaN      NaN      NaN      NaN        NaN
#
#        wordh    wordi      wordj wordsum workblks        workdiff  \
# 0    correct  correct    correct       9        6  strongly agree
# 1        NaN      NaN        NaN     NaN      NaN             NaN
# 2  incorrect  correct  incorrect       6        4           agree
# 3    correct  correct    correct       9        4  strongly agree
# 4        NaN      NaN        NaN     NaN      NaN             NaN
#
#          workfast                                   workfor1        workhard  \
# 0  strongly agree                         for-profit company             NaN
# 1             NaN                                        NaN   3rd important
# 2        disagree                         for-profit company   2nd important
# 3  strongly agree  non-profit or not-for-profit organization  most important
# 4             NaN                                        NaN  most important
#
#   workhsps workwhts  wrkgovt             wrkhome     wrksched        wrkslf  \
# 0        2        4  private  a few times a year    day shift  someone else
# 1      NaN      NaN  private                 NaN          NaN  someone else
# 2        4        4  private  a few times a year  night shift  someone else
# 3        4        4  private               never    day shift  someone else
# 4      NaN      NaN  private                 NaN          NaN  someone else
#
#   wrkslffam           wrkstat          wrktime                      wrktype  \
# 0       NaN  temp not working  not at all true  regular, permanent employee
# 1       NaN           retired              NaN                          NaN
# 2       NaN  working fulltime     not too true  regular, permanent employee
# 3       NaN  working fulltime        very true  regular, permanent employee
# 4       NaN           retired              NaN                          NaN
#
#                      wrkwayup      wtss   wtssall    wtssnr  wwwhr  wwwmin  \
# 0              agree strongly  2.357493  2.357493  2.753531   20.0     0.0
# 1                         NaN  0.942997  0.942997  1.101412    NaN     NaN
# 2  neither agree nor disagree  0.942997  0.942997  1.101412   10.0     0.0
# 3  neither agree nor disagree  0.942997  0.942997  1.101412    6.0     0.0
# 4                         NaN  0.942997  0.942997  1.101412    NaN     NaN
#
#         xmarsex      xmarsex1 xmovie        xnorcsiz  year yearsjob  yearsusa  \
# 0  always wrong  always wrong    NaN  uninc,med city  2018        1       NaN
# 1  always wrong           NaN     no  uninc,med city  2018       .i       NaN
# 2           NaN  always wrong     no  uninc,med city  2018       15       NaN
# 3           NaN           NaN     no  uninc,med city  2018       25       NaN
# 4  always wrong           NaN     no  uninc,med city  2018       .i       NaN
#
#   yearval  yousup    zodiac
# 0     NaN    45.0     virgo
# 1     NaN     NaN  aquarius
# 2     NaN     3.0     aries
# 3     NaN    10.0     aries
# 4     NaN     NaN    cancer

# %% [markdown]
# ### Problem 2
# #### Part a
# Use the `ProfileReport()` function to generate and embed an HTML formatted exploratory data analysis report in your notebook. Make sure that it includes a "Correlations" report along with "Overview" and "Variables". [1 point]

# %% [markdown]
# #### Part b
# Looking through the HTML report you displayed in part a, how many people in the data are from New England? [1 point]

# %% [markdown]
# #### Part c
# Looking through the HTML report you displayed in part a, which feature in the data has the highest number of missing values, and what percent of the values are missing for this feature? [1 point]

# %% [markdown]
# #### Part d
# Looking through the HTML report you displayed in part a, which two distinct features in the data have the highest correlation? [1 point]

# %% [markdown]
# ### Problem 3
# On a primetime show on a 24-hour cable news network, two unpleasant-looking men in suits sit across a table from each other, scowling. One says "This economy is failing the middle-class. The average American today is making less than \\$48,000 a year." The other screams "Fake news! The typical American makes more than \$55,000 a year!" Explain, using words and code, how the data can support both of their arguments. Use the sample weights to calculate descriptive statistics that are more representative of the American adult population as a whole. [1 point]

# %% [markdown]
# ### Problem 4
# For each of the following parts,
# * generate a table that provides evidence about the relationship between the two features in the data that are relevant to each question,
# * interpret the table in words,
# * use a hypothesis test to assess the strength of the evidence in the table,
# * and provide a **specific and accurate** intepretation of the $p$-value associated with this hypothesis test beyond "significant or not".
#
# #### Part a
# Is there a gender wage gap? That is, is there a difference between the average incomes of men and women? [2 points]

# %% [markdown]
# #### Part b
# Are there different average values of occupational prestige for different levels of job satisfaction? [2 points]

# %% [markdown]
# ### Problem 5
# Report the Pearson's correlation between years of education, socioeconomic status, income, occupational prestige, and a person's mother's and father's occupational prestige? Then perform a hypothesis test for the correlation between years of education and socioeconomic status and provide a **specific and accurate** intepretation of the $p$-value associated with this hypothesis test beyond "significant or not". [2 points]

# %% [markdown]
# ### Problem 6
# Create a new categorical feature for age groups, with categories for 18-35, 36-49, 50-69, and 70 and older (see the module 8 notebook for an example of how to do this).
#
# Then create a cross-tabulation in which the rows represent age groups and the columns represent responses to the statement that "It is much better for everyone involved if the man is the achiever outside the home and the woman takes care of the home and family." Rearrange the columns so that they are in the following order: strongly agree, agree, disagree, strongly disagree. Place row percents in the cells of this table.
#
# Finally, use a hypothesis test that can tell use whether there is enough evidence to conclude that these two features have a relationship, and provide a specific and accurate intepretation of the $p$-value. [2 points]

# %% [markdown]
# ### Problem 7
# For this problem, you will conduct and interpret a correspondence analysis on the categorical features that ask respondents to state the extent to which they agree or disagree with the statements:
# * "A working mother can establish just as warm and secure a relationship with her children as a mother who does not work."
# * "It is much better for everyone involved if the man is the achiever outside the home and the woman takes care of the home and family."
# * "Most men are better suited emotionally for politics than are most women."
# * "A preschool child is likely to suffer if his or her mother works."
# * "Family life often suffers because men concentrate too much on their work."

# %% [markdown]
# #### Part a
# Conduct a correspondence analysis using the observed features listed above that measures two latent features. Plot the two latent categories for each category in each of the features used in the analysis. [2 points]

# %% [markdown]
# #### Part b
# Display the latent features for every category in the observed features, sorted by the first latent feature. Describe in words what concept this feature is attempting to measure, and give the feature a name. [2 points]

# %% [markdown]
# #### Part c
# We can use the results of the MCA model to conduct some cool EDA. For one example, follow these steps:
#
# 1. Use the `.row_coordinates()` method to calculate values of the latent feature for every row in the data you passed to the MCA in part a. Extract the first column and store it in its own dataframe.
#
# 2. To join it with the full, cleaned GSS data based on row numbers (instead of on a primary key), use the `.join()` method. For example, if we named the cleaned GSS data `gss_clean` and if we named the dataframe in step 1 `latentfeature`, we can type
# ```
# gss_clean = gss_clean.join(latentfeature, how="outer")
# ```
# 3. Create a cross-tabuation with age categories (that you constructed in problem 5) in the rows and sex in the columns. Instead of a frequency, place the mean value of the latent feature in the cells.
#
# What does this table tell you about the relationship between sex, age, and the latent feature? [2 points]
